# %% [markdown]
# # Quickstart
# Minimal notebook scaffold for exploring the AI-TCAD surrogate repo.

# %%
import pandas as pd
from pathlib import Path
root = Path('..').resolve()
df = pd.read_csv(root / 'data' / 'raw_device_data.csv')
df.head()
# Out:
#    corner_radius_nm  gate_length_nm  oxide_thickness_nm  channel_thickness_nm  \
# 0          2.412286       20.112784            1.344490              5.821906
# 1          1.541084       15.356674            1.021404              4.475432
# 2          2.632355       21.435702            1.466681              6.276694
# 3          2.213157       17.809535            0.916879              4.625715
# 4          0.644861       11.390786            1.184554              4.243833
#
#    sheet_spacing_nm  channel_doping_cm3  sd_doping_cm3  stack_count     vgs_v  \
# 0         12.474571        2.390032e+17   7.472835e+19            1  0.278044
# 1         15.181846        2.223743e+17   4.567979e+19            2  0.082246
# 2         10.224468        4.665451e+15   1.984141e+19            3  0.241655
# 3          8.207820        1.321182e+15   3.077964e+20            3  0.645365
# 4         14.205240        1.005862e+16   2.674274e+19            1  0.394784
#
# ...
